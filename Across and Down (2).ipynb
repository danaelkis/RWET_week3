# %% [markdown]
# ### ACROSS AND DOWN

# %% [markdown]
# For a while, i haven’t done any crosswords.
#
# This is was one of my favourite morning routines in Tel Aviv, meet with my best friend Gil for coffee, he would drink his coffee, i would desperately look for a crosswords that no one made in the news papers and for 1 hour i would be day-dreaming to find the right answer for each clue. after solving the crosswords, we would still have another 20 minutes before heading to our offices. and then the fun would begin, because the crossword is over it doesn’t mean you cant use it, so for another 20 minutes i would try to write a short poem with the clues and answers of the crossword.
#
# I even had a small project where i scanned a crossword book that i bought in an airport and
# When I deleted the code, the grid, and the punctuation marks, that left only clues.  The clues became parts of sentences or words that asked, like the puzzle, to be solved and perhaps to be read as something new.
# link to "easy to solve" project"  - https://danaelkis.com/Easy-Crosswords-Fun-to-Solve
#
# I continue this fun experiment with the random + textwrap and
# add the ACROS and DOWN structure of the crossword.
# I took this link https://www.google.com/search?q=crosswords+clues+and+answers&source=lnms&tbm=isch&sa=X&ved=0ahUKEwiX8IqWnOHgAhUQPN8KHVWbBUUQ_AUIDygC&biw=1440&bih=766#imgrc=N3ToFNc7u2ayPM that someone put online with his answers to this crossword.
# the outcome was playful, some moments were interesting
# I really liked the headline of the 2 sections created by doing:
# DOWN/ACROSS the + random words from answers + of the + random words from answers.
#
# Examples that i liked:
# // Across the Take of the Are,
# // Down the Antic of the name,
# // Across the Egg of the Stir,
# // Down the Tete of the Govt,
# // Across the Pisa of the no,
# // Down the Eclat of the Elim,
# // Across the Arid of the Sob,
# // Down the Innies of the Tre,
# // Across the Orcs of the opah,
# // Across the Haste of the Ere,
# // Down the Glee of the Hay,
#
# Some sentenced that came out of the crossword clues were surprising
# the combination sometimes left me surprise to how abstract it can go or how accurate it can be
#
#
# ///
# left buttons the Fleece
# Hercules position of rock (so true)
#
# ///
# Liking Some lover’s beds
# Brain staple gas music (what is gas music? love it)
#
# ///
# blonde for theatre
# Secular to Brouhaha
# category Certain oil
# Wheel See creatures
# Cherished It Head Bribery
#
# ///
# blonde Occupy can’t
# capital Asian
#
# Maybe as a text generator its not the best of its kind, but when starting to look for some
# magical moments i like what i got. i found this task to be very hard. it actually took me more time to understand what are the materials i want to use. what i want to say (if i want to say something).
# I thought a lot about the idea of these experiments trying to take down a state of power. or reveal a new layer of a given text. it seems like to do it in english will be more hard since the poetry and my beloved and cherished texts are all in Hebrew but i am full power to reveal new ways to read / write and intterputate where i am right now.
# I think that going to the crosswords was an "easy" solution for me, maybe like the microphone checks. since it has a universal code of understanding what it is. i expect myself in the next assignment maybe to find a new category of texts and let my self be more critical.

# %%
import random
import textwrap

crosswords = """
User’s treatment
Moonfish
Captain of the pequot
Sister of Melpomene
Galileo’s birthplace
Honey
See 59-down
Ye
Many a cat lover’s acquisition
Bungle
Blubber
German ‘I’
Contents of some beds
City founded by Cadmus
Something with many seats
Basketball position
Air cells in the lung
Fleece
Contemptuous Expression
Signs
Changes
Product that prevents gas
Mexican indian tribe
Touch and go?
Brain waves?
Some belly buttons
Liking
Canceled
See 10-down
Expert
Parched
Pop music
Classic rock group
Hercules
Sensation
Person on the left
Scottish “own”
20 places?
Parts of some clown’s attire
Daily tv staple since 1986
"""

crosswords2 = """
Compassion
Shade of blonde
Reason for snizzin’
Circa
See 43-down
Take aboard a U.F.O
Movie theatre annoyance
Dungeons and dragons creatures
The Simpsons
Brouhaha
It can’t be
See 1-down
Cherished
Asian oil capital
Ludicrous
Stays flat
It’s often around 6%-8%
Place to put a banjo
Number
Head of Quebec
Celebrity
Wheel of fortune category
Have a shortage
Secular
Dakota indians
Scrape
Speed skater
Occupy a position
Certain tum
Bribery suffi
Be the right size
"""

answers = "Rehab Erato Deem worthy Red Ere Hae Atoms Bowties Stray Ich Orcs Oprah Pity Ash Hay fever opah Pisa Sob Thebes Incas Rook Stir Oh no become angry Baku Mutated Elim Tre Haste Innies Nogo Guru Styx Things Runout Sioux Tete Sale stax Antic Glee Loved Otto Govt Sneer Elim Take care of Arid xena Are Skin The da Laic Big name Eric Ell Ola Fit Milli Eclat Shine Tag Listen Egg Beano Inks Song Knee Lies Hallucinate Abduct beeper About  Foulup Ahab Babe Olde Lettuce".split()

print("Across the " + random.choice(answers) + " of the " + random.choice(answers)+ ",\n")

crosswords = crosswords.split()
random.shuffle(crosswords)
print(textwrap.fill(" ".join(crosswords), 25)+ ",\n")

print("Down the " + random.choice(answers) + " of the " + random.choice(answers)+ ",\n")

crosswords2 = crosswords2.split()
random.shuffle(crosswords2)
print(textwrap.fill(" ".join(crosswords2), 25))
# Out:
# Across the Nogo of the Skin,
#
# Changes a Captain tv
# 59-down of Brain of
# pequot Air staple Daily
# Fleece Expression group
# the Moonfish Touch
# Sensation of Signs
# Galileo’s waves? Sister
# the cat seats Many
# Canceled ‘I’ Expert belly
# Parts position prevents
# music in some Cadmus
# treatment the tribe
# lover’s attire with 20
# lung birthplace Contents
# Liking go? since Mexican
# clown’s See “own”
# Contemptuous acquisition
# cells Something founded
# Basketball indian that
# some left See buttons
# Melpomene of and City
# places? German beds Honey
# Scottish Person Product
# Hercules rock Pop User’s
# many on Ye 1986 Parched
# gas 10-down by Blubber
# Bungle Classic Some,
#
# Down the Nogo of the Skin,
#
# a of a category 43-down
# Have Reason Celebrity of
# See snizzin’ be annoyance
# Brouhaha indians
# Cherished Shade Be
# Bribery creatures the See
# for Certain It and a
# Compassion often a Dakota
# banjo right 6%-8% Stays
# Take tum Movie Secular of
# ...
